# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

# %%
base_url = 'https://lifehacker.ru/topics/technology/' # базовая часть ссылки, позже в цикле будем добавлять к ней пагинацию
response = requests.get('https://lifehacker.ru/topics/technology/?page=1') # получаем контент первой страиниц
soup = BeautifulSoup(response.text, 'lxml') # инициализируем объект bs4 и задаем парсер lxml

raw_items = soup.find_all('a', class_='lh-small-article-card__link')  # ищем все a-элементы с классом tm-article-comments-counter-link__link
links = [item.get('href') for item in raw_items] # получаем у ссылок только href-атрибут, убираем подстроку '/comments'
links
# Out:
# ['/chto-luchshe-displayport-ili-hdmi/',
#  '/kitaiskie-ultrasmartfony-mogut-ischeznut/',
#  '/sony-psp-v-2026-godu/',
#  '/vyxod-iphone-18/',
#  '/alternativy-messendzheram/',
#  '/samye-prodavaemye-smartfony-2/',
#  '/predstavlen-ruchnoi-ventilyator-dyson/',
#  '/obzor-honor-600-lite/',
#  '/velosipednyi-zvonok-shkody/',
#  '/zachem-nuzhen-amerikanskij-apple-id-kak-ego-besplatno-zaregistrirovat/',
#  '/pebblebee-vypustila-analog-airtag-s-sirenoj-i-fonarikom-eto-lichnaya-trevozhnaya-knopka/',
#  '/anons-oneplus-nord-6/',
#  '/gemini-nejroset/',
#  '/apple-gotovit-novyi-macbook-neo/',
#  '/anons-artemis-watch-2-0/',
#  '/chto-luchshe-iphone-17-ili-iphone-17-pro/',
#  '/vyyavlyat-vpn-na-iphone-budet-slozhno/',
#  '/ak-skryt-lico-na-foto-na-aifon/',
#  '/kak-otkryt-fajl-heic-na-kompyutere/',
#  '/prilozhenija-ios-mart-2026/',
#  '/ryukzak-s-klimat-kontrolem/',
#  '/messendzher-maks-na-pk/',
#  '/apple-soxranit-rossiyanam-dostup-k-dannym-icloud-posle-okonchaniya-podpiski/',
#  '/dostup-k-rossiiskim-saitam/',
#  '/kak-perenesti-muzyku-v-yandex-muzyku/',
#  '/domashnyaya-ii-kamera-xiaomi/',
#  '/nazvany-10-samyx-moshhnyx-smartfonov-marta-v-tope-srazu-tri-modeli-honor/',
#  '/lunnaya-missiya-artemida-2/',
#  '/polnaya-blokirovka-telegram/',
#  '/besplatnye-onlajn-servisy-mart-2026/']

# %%
parsed_urls = []

for page_num in range(1, 11):
    url = f'{base_url}/?page={page_num}' # подставляем нужный номер страницы для пагинации, дальше парсим каждую страницу аналогично коду выше
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    raw_items = soup.find_all('a', class_='lh-small-article-card__link')
    parsed_urls += [item.get('href') for item in raw_items]

# %%
len(parsed_urls) # 10 страниц X 30 статей
# Out:
# 300

# %%
base_url = 'https://lifehacker.ru'
response = requests.get('https://lifehacker.ru/chto-luchshe-displayport-ili-hdmi/')
soup = BeautifulSoup(response.text, 'lxml')
soup.find('article', class_='single-article__post-content single-article__content-container').text
# Out:
# 'Первый попавшийся кабель с подходящими разъёмами, конечно, будет работать с монитором или телевизором, но может легко лишить вас повышенной герцовки или полезных функций. DisplayPort и HDMI только с виду похожи, на деле же у них совсем разные задачи. Разберёмся, какой выжмет максимум из вашего железа, в чём их реальная разница и что будет лучше для\xa0вас.Что такое DisplayPort и\xa0HDMIDisplayPort (слева) выглядит как прямоугольник со скошенным углом и кнопкой-защёлкой, а HDMI —\xa0как симметричная трапеция. Иллюстрация: Артём Козориз / GeminiDisplayPort и HDMI — самые распространённые интерфейсы для вывода изображения c компьютера, ноутбука, консоли или медиаплеера на монитор, телевизор или проектор. Они во многом похожи: оба передают картинку и звук, но создавались и развивались по-разному:DisplayPort (DP) — это сугубо компьютерная история. Стандарт был разработан ассоциацией VESA как замена старым портам VGA и DVI в ПК. Он изначально спроектирован для работы с высокими частотами обновления и несколькими мониторами.\nHDMI (High-Definition Multimedia Interface), наоборот, массовый стандарт для бытовой электроники. Его развивает консорциум крупных производителей техники: Sony, Panasonic и другие. Основной упор в нём сделан на простом и универсальном подключении телевизоров к внешним устройствам: ТВ-приставкам, игровым консолям, плеерам и остальной видеотехнике.\nЧем DisplayPort отличается от\xa0HDMIПомимо формы штекера, разница между интерфейсами кроется в их архитектуре и способе передачи данных. DisplayPort работает подобно компьютерной сети и отправляет данные пакетами. Это позволяет распределять огромные потоки информации и достигать сверхвысоких частот обновления. Благодаря технологии MST (Multi-Stream Transport) к одному физическому выходу видеокарты можно подключить несколько дисплеев цепочкой.HDMI отличается продвинутой работой со звуком и управлением техникой, которых нет у DP. Функция eARC (Enhanced Audio Return Channel) позволяет передавать несжатый многоканальный звук Dolby Atmos в обе стороны по одному кабелю. А благодаря технологии CEC (Consumer Electronics Control) устройства могут «общаться» друг с другом. Так, при запуске PS5 телевизор включится сам и сразу выберет нужный вход.Если говорить о характеристиках, то различия будут такими:DisplayPort 2.1 (UHBR)HDMI 2.1Максимальная пропускная способностьДо 80 Гбит/сДо 48 Гбит/сМаксимальное разрешение16K @ 60 Гц / 4K @ 480\xa0Гц8K @ 60 Гц / 4K @ 240\xa0ГцОсобенностьDaisy Chaining (MST)ARC / eARC (для\xa0звука)Максимальная длина кабеля без потерьДо 2\xa0мДо 3\xa0мУчитывайте, что возможности системы ограничены самым слабым звеном. Реальная скорость будет зависеть от того, какую версию поддерживает сам кабель, а также оба устройства, которые подключены им.Какие преимущества и недостатки есть у DisplayPortКадр: RTINGS Computer / YouTubeСильные стороны этого стандарта лучше всего раскрываются именно на рабочем столе, в связке мощной видеокарты и современного монитора. Вот\xa0они:Многомониторность. Как уже говорилось выше, благодаря ей дисплеи можно подсоединять один к другому, не занимая порты в ПК и улучшая кабель-менеджмент.\nСтабильный гейминг. Адаптивная синхронизация (G‑Sync и FreeSync) здесь работает чище и без лишних задержек.\nФиксация. Механические защёлки на штекере не дают кабелю случайно выскочить из разъёма при повороте монитора.\nНо и без минусов тоже не обошлось:Узкая специализация. Порт практически не встречается в телевизорах, игровых приставках и медиаплеерах.\nОграничение длины. Сигнал быстро затухает, поэтому длина кабеля обычно не больше 2\xa0м.\nКакие преимущества и недостатки есть у\xa0HDMIКадр: Digital Trends / YouTubeЭтот интерфейс стал мировым стандартом благодаря своей простоте и способности объединять самую разную технику. Основные плюсы тут\xa0такие:Распространённость. Порт есть в каждом телевизоре, консоли, ноутбуке и проекторе. Не нужны переходники.\nУдобство (CEC). Можно управлять всей техникой одним пультом.\nРабота со звуком. Технология  ...

# %%
soup.find('h1', class_='article-card__title').text
# Out:
# 'Что лучше — DisplayPort или\xa0HDMI'

# %%
result = []

for url in tqdm(parsed_urls):
    article = {}

    article_url = f'{base_url}{url}' # подставляем часть ссылки, ведущую материал
    response = requests.get(article_url)
    soup = BeautifulSoup(response.text, 'lxml')

    article['title'] = soup.find('h1', class_='article-card__title').text # Получаем текст из в первом h1
    article['text'] = soup.find('article', class_='single-article__post-content single-article__content-container').text # Получаем весь текст

    result.append(article)
# Out:
# 100%|██████████| 300/300 [05:50<00:00,  1.17s/it]

# %%
pd.set_option('display.max_colwidth', 400)

# %%
data = pd.DataFrame(result)
data.head()
# Out:
#                                                                                                    title  \
# 0                                                                       Что лучше — DisplayPort или HDMI
# 1                                                Новые китайские Ultra‑смартфоны могут не выйти на рынок
# 2                                 Зачем я купил Sony PSP в 2026 году — и почему советую эту легенду всем
# 3                                                  Apple выпустит сразу три смартфона в начале 2027 года
# 4  Звони коту: как из-за блокировок люди начали общаться через автокормушки, пылесосы, таблицы и заметки
#
#                                                                                                                                                                                                                                                                                                                                                                                                               text
# 0  Первый попавшийся кабель с подходящими разъёмами, конечно, будет работать с монитором или телевизором, но может легко лишить вас повышенной герцовки или полезных функций. DisplayPort и HDMI только с виду похожи, на деле же у них совсем разные задачи. Разберёмся, какой выжмет максимум из вашего железа, в чём их реальная разница и что будет лучше для вас.Что такое DisplayPort и HDMIDisplayPort (...
# 1  Некоторые китайские производители могут временно отказаться от разработки продвинутых Ultra‑смартфонов из‑за роста стоимости оперативной памяти и других комплектующих. Об этом сообщили инсайдеры Ice Universe и Digital Chat Station.Конкретные бренды не называются, однако речь может идти о Xiaomi, Oppo и Vivo, поскольку именно они выпускают наиболее известные Ultra‑флагманы. В Китае такие устрой...
# 2  Покупка консоли 20-летней давности сегодня выглядит странно. Но именно PSP предлагает опыт и ощущения, которых не дают современные перегруженные устройства. Расскажу, зачем я взял этот гаджет в 2026 году, поделюсь своим мнением и подскажу, на что стоит обратить внимание, если вы решите повторить этот опыт.Зачем всё это, когда есть Switch, Steam Deck, консоли-эмуляторы и смартфоныСразу исповеда...
# 3  Марк Гурман из Bloomberg сообщил, что в начале 2027 года Apple планирует выпустить сразу три смартфона. Обычно весной компания ограничивалась одной бюджетной моделью.В следующем году формат изменится: купертинцы представят обновлённый iPhone Air, доступный iPhone 18e и стандартный iPhone 18. Презентация ожидается в марте или апреле, но пока неясно, будет ли она транслироваться в привычном форм...
# 4  В России блокируют Telegram и WhatsApp, созваниваться и списываться через привычные приложения становится неудобно или вовсе невозможно. Поэтому приходится выкручиваться: приспосабливать под общение сервисы, изначально совершенно для этого не предназначенные.АвитоОдна из самых громких историй по теме произошла в марте. Жительница Санкт-Петербурга использовала площадку объявлений вместо мессенд...
